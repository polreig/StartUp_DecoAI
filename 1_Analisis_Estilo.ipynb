# %% [markdown]
# <a href="https://colab.research.google.com/github/polreig/StartUp_DecoAI/blob/main/1_Analisis_Estilo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalar librerías necesarias

# %%
# !pip install -q -U google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.9/750.9 kB 57.4 MB/s eta 0:00:00

# %% [markdown]
# ## Importar librerías y guardar API key

# %%
from google import genai
from google.colab import userdata
from PIL import Image
import requests
from io import BytesIO

# Cargamos la clave de forma segura
GOOGLE_API_KEY = userdata.get('clave_API_gemini')
client = genai.Client(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ## Función para analizar la habitación

# %%
def analizar_habitacion(ruta_imagen_o_url, texto_usuario):
    # Cargamos la imagen
    if ruta_imagen_o_url.startswith('http'):
        response = requests.get(ruta_imagen_o_url)
        imagen = Image.open(BytesIO(response.content))
    else:
        imagen = Image.open(ruta_imagen_o_url)

    # Creamos el Prompt
    prompt = f"""
    Eres un diseñador de interiores profesional.
    Analiza la imagen adjunta de esta habitación actual y el siguiente mensaje del cliente: '{texto_usuario}'.

    Por favor, responde con la siguiente estructura:
    1. Estilo Actual: Describe en una frase el estilo y estado actual de la habitación.
    2. Recomendación de Estilo: Basado en lo que pide el cliente, ¿qué estilo específico le recomiendas?
    3. Elementos Clave: Enumera 3 muebles o decoraciones esenciales para lograr la transformación.
    4. Paleta de Colores: Sugiere 3 colores para el nuevo estilo.
    """

    # Nueva forma de llamar al modelo
    respuesta = client.models.generate_content(
        model='gemini-2.5-flash',
        contents=[imagen, prompt]
    )

    return respuesta.text

# %% [markdown]
# ## Prueba

# %%
# Prueba con una foto de ejemplo
url_foto_prueba = "https://concept-u.es/cdn/shop/articles/habitacion-comoda.webp?v=1703692446"
peticion_cliente = "Quiero que la habitación sea más colorida"

resultado = analizar_habitacion(url_foto_prueba, peticion_cliente)
print(resultado)
# Out:
# ¡Absolutamente! Entiendo perfectamente el deseo de inyectar más vida y personalidad a la habitación. Aquí tienes mi análisis y recomendaciones:
#
# 1.  **Estilo Actual:** La habitación actual presenta un estilo minimalista y escandinavo, dominado por tonos neutros y materiales naturales, creando una atmósfera serena y limpia, pero con una clara falta de vitalidad cromática.
#
# 2.  **Recomendación de Estilo:** Basándonos en tu deseo de "más color", te recomiendo un **Estilo Bohemio Moderno (Boho Modern)**. Este estilo fusiona la calidez y la riqueza de texturas del boho con las líneas limpias y la funcionalidad del diseño moderno, permitiendo una gran introducción de color sin perder la sofisticación.
#
# 3.  **Elementos Clave:**
#     *   **Textiles Vibrantes y con Patrones:** Introduce un edredón o manta de cama con patrones geométricos o étnicos en colores vivos, y añade varios cojines decorativos de diferentes texturas y tonalidades intensas para la cama.
#     *   **Arte de Pared Expresivo:** Incorpora una gran pieza de arte abstracto o un conjunto de láminas con ilustraciones coloridas y motivos botánicos o étnicos sobre la pared lisa o incluso integrada en el cabecero de listones.
#     *   **Alfombra de Área con Carácter:** Reemplaza la alfombra actual por una más grande y con un diseño llamativo, ya sea un patrón geométrico atrevido, un estampado marroquí o una textura rica en tonos cálidos.
#
# 4.  **Paleta de Colores:** Para el nuevo estilo, te sugiero una combinación que complemente la base neutra existente y aporte calidez y alegría:
#     *   **Terracota:** Un rojo-naranja tierra que aporta calidez y una conexión orgánica.
#     *   **Verde Salvia o Oliva:** Un verde suave y natural que añade frescura y armonía, haciendo eco de la planta existente.
#     *   **Mostaza o Naranja Quemado:** Un amarillo profundo o un naranja rojizo que actuará como acento vibrante, aportando energía y luminosidad.
