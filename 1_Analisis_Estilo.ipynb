# %% [markdown]
# <a href="https://colab.research.google.com/github/polreig/StartUp_DecoAI/blob/main/1_Analisis_Estilo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalar librerías necesarias

# %%
# !pip install -q -U google-genai
# Out:
# "pip" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %% [markdown]
# ## Importar librerías y guardar API key

# %%
from google import genai
from google.colab import userdata
from PIL import Image
import requests
from io import BytesIO

# Cargamos la clave de forma segura
GOOGLE_API_KEY = userdata.get('clave_API_gemini')
client = genai.Client(api_key=GOOGLE_API_KEY)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google import genai
#       2 from google.colab import userdata
#       3 from PIL import Image
#
# ImportError: cannot import name 'genai' from 'google' (unknown location)

# %% [markdown]
# ## Función para analizar la habitación

# %%
def analizar_habitacion(ruta_imagen_o_url, texto_usuario):
    # Cargamos la imagen
    if ruta_imagen_o_url.startswith('http'):
        response = requests.get(ruta_imagen_o_url)
        imagen = Image.open(BytesIO(response.content))
    else:
        imagen = Image.open(ruta_imagen_o_url)

    # Creamos el Prompt
    prompt = f"""
    Eres un diseñador de interiores profesional.
    Analiza la imagen adjunta de esta habitación actual y el siguiente mensaje del cliente: '{texto_usuario}'.

    Por favor, responde con la siguiente estructura:
    1. Estilo Actual: Describe en una frase el estilo y estado actual de la habitación.
    2. Recomendación de Estilo: Basado en lo que pide el cliente, ¿qué estilo específico le recomiendas?
    3. Elementos Clave: Enumera 3 muebles o decoraciones esenciales para lograr la transformación.
    4. Paleta de Colores: Sugiere 3 colores para el nuevo estilo.
    """

    # 3. Nueva forma de llamar al modelo
    respuesta = client.models.generate_content(
        model='gemini-2.5-flash',
        contents=[imagen, prompt]
    )

    return respuesta.text

# %% [markdown]
# ## Prueba

# %%
# Prueba con una foto de ejemplo
url_foto_prueba = "https://concept-u.es/cdn/shop/articles/habitacion-comoda.webp?v=1703692446"
peticion_cliente = "Quiero que la habitación sea más colorida"

resultado = analizar_habitacion(url_foto_prueba, peticion_cliente)
print(resultado)
# Out:
# ¡Claro que sí! Con gusto te ayudaré a transformar tu habitación en un espacio más vibrante y acogedor.
#
# ---
#
# 1.  **Estilo Actual:** La habitación actual presenta un estilo nórdico y minimalista, caracterizado por una paleta de colores neutros y materiales naturales, creando un ambiente sereno pero con poca vivacidad.
#
# 2.  **Recomendación de Estilo:** Te recomiendo un estilo **Boho-Chic Contemporáneo**, que te permitirá incorporar color y texturas orgánicas manteniendo la base de tus muebles actuales y añadiendo una sensación de calidez y personalidad relajada.
#
# 3.  **Elementos Clave:**
#     *   **Alfombra de Área con Patrón y Color:** Reemplaza la alfombra actual por una con un diseño geométrico sutil o étnico en tonos cálidos o terrosos para anclar el espacio y añadir un toque vibrante.
#     *   **Textiles Decorativos:** Incorpora cojines de diferentes texturas (lino, algodón, macramé) en la cama con colores que complementen la nueva paleta, y una manta a pie de cama con flecos o un tejido interesante.
#     *   **Arte Mural Abstracto o Botánico:** Añade una pieza grande de arte sobre la pared de lamas de madera (quizás con colores que rompan el vertical de la pared) o en la pared adyacente para introducir color y un punto focal.
#
# 4.  **Paleta de Colores:**
#     *   **Verde Oliva/Salvia:** Un tono terroso y relajante que complementa el verde de tu planta y añade frescura.
#     *   **Terracota/Naranja Quemado:** Un color cálido y envolvente que aporta energía y una conexión con lo artesanal del estilo Boho.
#     *   **Azul Polvoriento/Teal Suave:** Un color que introduce calma y profundidad, creando un contraste armonioso con los tonos cálidos.
